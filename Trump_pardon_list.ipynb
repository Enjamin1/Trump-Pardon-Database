# %% [markdown]
# <a href="https://colab.research.google.com/github/Enjamin1/Trump-Pardon-Database/blob/main/Trump_pardon_list.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# TRUMP PARDON'S

# %%
def find_names(x):
  name = item[x].text
  print("Name:        ", name)
  return

# %%
def find_district(x):
  district = item[x].text
  print("District:    ",district)
  return

# %%
def find_sentance(x):
  sentance = item[x].text
  print("Sentance:    ",sentance)
  return

# %%
def find_crime(x):
  crime = item[x].text
  print("Crime:       ",crime)
  return

# %%
import sqlite3
import urllib.request, urllib.parse, urllib.error
from bs4 import BeautifulSoup
import ssl


list1 = list()



ssl._create_default_https_context = ssl._create_unverified_context
url = 'https://www.justice.gov/pardon/pardons-granted-president-donald-trump'
user_agent = 'Mozilla/5.0 (Windows; U; Windows NT 5.1; en-US; rv:1.9.0.7) Gecko/2009021910 Firefox/3.0.7'


#url = "https://www.yesbank.in/pdf/forexcardratesenglish_pdf"
headers={'User-Agent':user_agent,}
request=urllib.request.Request(url,None,headers)


#read and parse the html
r = urllib.request.urlopen(request).read().decode()
soup = BeautifulSoup(r, 'html.parser')


#searching for the part of the site where the pardons are
tags = soup.find_all('table', attrs={'summary':'This table provides information on the Number of Pardons Granted by President Trump'})


# tag ~ the dates trump pardoned people and appending them to list

count = 0
for tag in tags:
  dates = tag.find_all('tr')

  for pardon in dates:
    listp = pardon.find_all('td')
    list1.append(listp)

for item in list1:
  try:
    if len(item) < 1:
      continue
    else:
      count += 1
      print("Pardon #",count)
      find_names(0)
      find_district(1)
      find_sentance(2)
      find_crime(3)

      print('\n')
  except:
    pass
print('Total pardons issued by President Trump: ',count)
# Out:
# Pardon # 1
# Name:         Joseph M. Arpaio
# District:     District of Arizona
# Sentance:     N/A
# Crime:        Contempt of court
#
#
# Pardon # 2
# Name:         Kristian Mark Saucier
# District:     District of Connecticut
# Sentance:     12 months' imprisonment and three years' supervised release, conditioned upon six months' home confinement and the performance of 100 hours' community service (August 19, 2016)
# Crime:        Unauthorized retention of defense information
#
#
# Pardon # 3
# Name:         I. Lewis Libby, aka Scooter Libby, aka Irve Lewis “Scooter” Libby
# District:     District of Columbia
# Sentance:     30 months' imprisonment, two years' supervised release, $250,000 fine (June 14, 2007)
# Crime:        Obstruction of justice; false statements; perjury (two counts)
#
#
# Pardon # 4
# Name:         John Arthur Johnson, aka Jack Johnson
# District:     Northern District of Illinois
# ...
